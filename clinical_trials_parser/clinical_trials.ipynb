# %%
import os
import time
import math
import requests
import pandas as pd
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

def export_clinical_trials_texts(
    search_term="cancer",
    csv_path="clinical_trials_cancer.csv",
    txt_dir="studies_txt",
    page_size=1000,
    batch_size=200,
    checkpoint_every=10,
    user_agent="Mozilla/5.0 (compatible; ctg-bot/1.0)"
):
    """
    Скачивает исследования с ClinicalTrials.gov по поисковому термину, 
    сохраняет CSV и TXT файлы.

    По умолчанию:
      - search_term = "cancer"
      - CSV = clinical_trials_cancer.csv
      - TXT = ./studies_txt
    """
    API_BASE = "https://clinicaltrials.gov/api/v2/studies"
    HEADERS = {"User-Agent": user_agent, "Accept": "application/json"}

    # ---- сессия с ретраями ----
    def make_session():
        s = requests.Session()
        retry = Retry(
            total=5, backoff_factor=0.5,
            status_forcelist=(429, 500, 502, 503, 504),
            allowed_methods=frozenset(["GET"]),
        )
        s.mount("https://", HTTPAdapter(max_retries=retry))
        s.headers.update(HEADERS)
        return s

    # ---- утилиты ----
    def join_semicolon(values):
        if not values:
            return ""
        return "; ".join(str(v).strip() for v in values if v)

    def outcome_measures(outcomes):
        if not outcomes:
            return ""
        return "; ".join(
            o.get("measure") for o in outcomes
            if isinstance(o, dict) and o.get("measure")
        )

    def interventions_fmt(interventions):
        if not interventions:
            return ""
        items = []
        for iv in interventions:
            name = iv.get("name")
            typ  = iv.get("type")
            if name and typ:
                items.append(f"{typ}: {name}")
            elif name:
                items.append(name)
        return join_semicolon(items)

    # ---- 1) все NCT ID ----
    def fetch_all_nct_ids(session):
        params = {
            "format": "json",
            "pageSize": page_size,
            "fields": "protocolSection.identificationModule.nctId",
            "query.term": search_term,
            "countTotal": "true",
        }
        ncts, page_token, page = [], None, 0
        while True:
            if page_token:
                params["pageToken"] = page_token
            else:
                params.pop("pageToken", None)
            r = session.get(API_BASE, params=params, timeout=60)
            if r.status_code != 200:
                raise RuntimeError(f"NCT IDs error {r.status_code}: {r.text[:500]}")
            data = r.json()
            studies = data.get("studies", []) or []
            page += 1
            print(f"[nct_ids] page {page}, items: {len(studies)}")
            for s in studies:
                nct = (s.get("protocolSection", {})
                        .get("identificationModule", {})
                        .get("nctId"))
                if nct: ncts.append(nct)
            page_token = data.get("nextPageToken")
            if not page_token:
                break
            time.sleep(0.1)
        unique_sorted = sorted(set(ncts))
        print(f"[nct_ids] total unique: {len(unique_sorted)}")
        return unique_sorted

    # ---- 2) детали по батчу ----
    DETAIL_FIELDS = ",".join([
        "protocolSection.identificationModule.nctId",
        "protocolSection.identificationModule.briefTitle",
        "protocolSection.identificationModule.officialTitle",
        "protocolSection.descriptionModule.briefSummary",
        "protocolSection.descriptionModule.detailedDescription",
        "protocolSection.conditionsModule.conditions",
        "protocolSection.armsInterventionsModule.interventions",
        "protocolSection.outcomesModule.primaryOutcomes",
        "protocolSection.outcomesModule.secondaryOutcomes",
        "protocolSection.outcomesModule.otherOutcomes",
        "hasResults",
    ])

    def fetch_details_for_batch(session, nct_batch):
        params = {
            "format": "json",
            "pageSize": len(nct_batch),
            "query.id": ",".join(nct_batch),
            "fields": DETAIL_FIELDS,
        }
        r = session.get(API_BASE, params=params, timeout=60)
        if r.status_code != 200:
            print(f"[details] error {r.status_code}, filling blanks for {len(nct_batch)} ids")
            return [{
                "NCTId": n,
                "Study Title": "", "Brief Summary": "", "Conditions": "", "Interventions": "",
                "Primary Outcome Measures": "", "Secondary Outcome Measures": "", "Other Outcome Measures": "",
                "Researcher Description": "", "Results URL": None
            } for n in nct_batch]

        data = r.json()
        studies = data.get("studies", []) or []
        by_id = {(
            s.get("protocolSection", {})
             .get("identificationModule", {})
             .get("nctId")
        ): s for s in studies if s.get("protocolSection")}

        rows = []
        for nct in nct_batch:
            s  = by_id.get(nct, {})
            ps = s.get("protocolSection", {}) if s else {}

            ident = ps.get("identificationModule", {}) or {}
            descm = ps.get("descriptionModule", {}) or {}
            condm = ps.get("conditionsModule", {}) or {}
            aim   = ps.get("armsInterventionsModule", {}) or {}
            outm  = ps.get("outcomesModule", {}) or {}

            title = ident.get("briefTitle") or ident.get("officialTitle") or ""
            brief = (descm.get("briefSummary") or "").strip()
            detailed = (descm.get("detailedDescription") or "").strip()
            conditions = join_semicolon(condm.get("conditions"))
            interventions = interventions_fmt(aim.get("interventions"))
            primary = outcome_measures(outm.get("primaryOutcomes"))
            secondary = outcome_measures(outm.get("secondaryOutcomes"))
            other = outcome_measures(outm.get("otherOutcomes"))
            has_results = bool(s.get("hasResults"))
            results_url = f"https://clinicaltrials.gov/study/{nct}?tab=results" if has_results else None

            rows.append({
                "NCTId": nct,
                "Study Title": title,
                "Brief Summary": brief,
                "Conditions": conditions,
                "Interventions": interventions,
                "Primary Outcome Measures": primary,
                "Secondary Outcome Measures": secondary,
                "Other Outcome Measures": other,
                "Researcher Description": detailed,
                "Results URL": results_url,
            })
        return rows

    # ---- 3) основной цикл ----
    session = make_session()
    nct_ids = fetch_all_nct_ids(session)

    all_rows = []
    batches = math.ceil(len(nct_ids) / batch_size)
    for i in range(batches):
        batch = nct_ids[i*batch_size:(i+1)*batch_size]
        print(f"[details] batch {i+1}/{batches} size {len(batch)}")
        rows = fetch_details_for_batch(session, batch)
        all_rows.extend(rows)
        if checkpoint_every and ((i + 1) % checkpoint_every == 0):
            pd.DataFrame(all_rows).to_csv(csv_path, index=False, encoding="utf-8-sig")
            print(f"[checkpoint] saved {len(all_rows)} rows -> {csv_path}")
        time.sleep(0.1)

    cols = [
        "NCTId","Study Title","Brief Summary","Conditions","Interventions",
        "Primary Outcome Measures","Secondary Outcome Measures","Other Outcome Measures",
        "Researcher Description","Results URL"
    ]
    df = pd.DataFrame(all_rows, columns=cols)
    df.to_csv(csv_path, index=False, encoding="utf-8-sig")
    print(f"[done] saved {csv_path}: {len(df)} rows")

    # ---- 4) TXT-экспорт ----
    os.makedirs(txt_dir, exist_ok=True)

    def merge_fields(row):
        fields = [
            row.get("Study Title", ""),
            row.get("Brief Summary", ""),
            row.get("Conditions", ""),
            row.get("Interventions", ""),
            row.get("Primary Outcome Measures", ""),
            row.get("Secondary Outcome Measures", ""),
            row.get("Other Outcome Measures", ""),
            row.get("Researcher Description", ""),
        ]
        return "\n".join(str(f) for f in fields if str(f).strip())

    for idx, row in df.iterrows():
        text = merge_fields(row)
        if text.strip():
            fname = f"{idx+1:05d}.txt"
            with open(os.path.join(txt_dir, fname), "w", encoding="utf-8") as f:
                f.write(text)

    print(f"[texts] saved {len(df)} txt files -> {txt_dir}")
    return df

# %%
export_clinical_trials_texts()
# Out:
# [nct_ids] page 1, items: 1000
# [nct_ids] page 2, items: 1000
# [nct_ids] page 3, items: 1000
# [nct_ids] page 4, items: 1000
# [nct_ids] page 5, items: 1000
# [nct_ids] page 6, items: 1000
# [nct_ids] page 7, items: 1000
# [nct_ids] page 8, items: 1000
# [nct_ids] page 9, items: 1000
# [nct_ids] page 10, items: 1000
# [nct_ids] page 11, items: 1000
# [nct_ids] page 12, items: 1000
# [nct_ids] page 13, items: 1000
# [nct_ids] page 14, items: 1000
# [nct_ids] page 15, items: 1000
# [nct_ids] page 16, items: 1000
# [nct_ids] page 17, items: 1000
# [nct_ids] page 18, items: 1000
# [nct_ids] page 19, items: 1000
# [nct_ids] page 20, items: 1000
# [nct_ids] page 21, items: 1000
# [nct_ids] page 22, items: 1000
# [nct_ids] page 23, items: 1000
# [nct_ids] page 24, items: 1000
# [nct_ids] page 25, items: 1000
# [nct_ids] page 26, items: 1000
# [nct_ids] page 27, items: 1000
# [nct_ids] page 28, items: 1000
# [nct_ids] page 29, items: 1000
# [nct_ids] page 30, items: 1000
# [nct_ids] page 31, items: 1000
# [nct_ids] page 32, items: 1000
# [nct_ids] page 33, items: 1000
# [nct_ids] page 34, items: 1000
# [nct_ids] page 35, items: 1000
# [nct_ids] page 36, items: 1000
# [nct_ids] page 37, items: 1000
# [nct_ids] page 38, items: 1000
# [nct_ids] page 39, items: 1000
# [nct_ids] page 40, items: 1000
# [nct_ids] page 41, items: 1000
# [nct_ids] page 42, items: 1000
# [nct_ids] page 43, items: 1000
# [nct_ids] page 44, items: 1000
# [nct_ids] page 45, items: 1000
# [nct_ids] page 46, items: 1000
# [nct_ids] page 47, items: 1000
# [nct_ids] page 48, items: 1000
# [nct_ids] page 49, items: 1000
# [nct_ids] page 50, items: 1000
# [nct_ids] page 51, items: 1000
# [nct_ids] page 52, items: 1000
# [nct_ids] page 53, items: 1000
# [nct_ids] page 54, items: 1000
# [nct_ids] page 55, items: 1000
# [nct_ids] page 56, items: 1000
# [nct_ids] page 57, items: 1000
# [nct_ids] page 58, items: 1000
# [nct_ids] page 59, items: 1000
# [nct_ids] page 60, items: 1000
# [nct_ids] page 61, items: 1000
# [nct_ids] page 62, items: 1000
# [nct_ids] page 63, items: 1000
# [nct_ids] page 64, items: 1000
# [nct_ids] page 65, items: 1000
# [nct_ids] page 66, items: 1000
# [nct_ids] page 67, items: 1000
# [nct_ids] page 68, items: 1000
# [nct_ids] page 69, items: 1000
# [nct_ids] page 70, items: 1000
# [nct_ids] page 71, items: 1000
# [nct_ids] page 72, items: 1000
# [nct_ids] page 73, items: 1000
# [nct_ids] page 74, items: 1000
# [nct_ids] page 75, items: 1000
# [nct_ids] page 76, items: 1000
# [nct_ids] page 77, items: 1000
# [nct_ids] page 78, items: 1000
# [nct_ids] page 79, items: 1000
# [nct_ids] page 80, items: 1000
# [nct_ids] page 81, items: 1000
# [nct_ids] page 82, items: 1000
# [nct_ids] page 83, items: 1000
# [nct_ids] page 84, items: 1000
# [nct_ids] page 85, items: 1000
# [nct_ids] page 86, items: 1000
# [nct_ids] page 87, items: 1000
# [nct_ids] page 88, items: 1000
# [nct_ids] page 89, items: 1000
# [nct_ids] page 90, items: 1000
# [nct_ids] page 91, items: 1000
# [nct_ids] page 92, items: 1000
# [nct_ids] page 93, items: 1000
# [nct_ids] page 94, items: 1000
# [nct_ids] page 95, items: 1000
# [nct_ids] page 96, items: 1000
# [nct_ids] page 97, items: 1000
# [nct_ids] page 98, items: 1000
# [nct_ids] page 99, items: 1000
# [nct_ids] page 100, items: 1000
# [nct_ids] page 101, items: 1000
# [nct_ids] page 102, items: 1000
# [nct_ids] page 103, items: 1000
# [nct_ids] page 104, items: 1000
# [nct_ids] page 105, items: 1000
# [nct_ids] page 106, items: 1000
# [nct_ids] page 107, items: 1000
# [nct_ids] page 108, items: 1000
# [nct_ids] page 109, items: 1000
# [nct_ids] page 110, items: 1000
# [nct_ids] page 111, items: 1000
# [nct_ids] page 112, items: 1000
# [nct_ids] page 113, items: 1000
# [nct_ids] page 114, items: 1000
# [nct_ids] page 115, items: 1000
# [nct_ids] page 116, items: 1000
# [nct_ids] page 117, items: 1000
# [nct_ids] page 118, items: 1000
# [nct_ids] page 119, items: 1000
# [nct_ids] page 120, items: 1000
# [nct_ids] page 121, items: 1000
# [nct_ids] page 122, items: 1000
# [nct_ids] page 123, items: 1000
# [nct_ids] page 124, items: 1000
# [nct_ids] page 125, items: 1000
# [nct_ids] page 126, items: 1000
# [nct_ids] page 127, items: 1000
# [nct_ids] page 128, items: 1000
# [nct_ids] page 129, items: 1000
# [nct_ids] page 130, items: 1000
# [nct_ids] page 131, items: 1000
# [nct_ids] page 132, items: 1000
# [nct_ids] page 133, items: 746
# [nct_ids] total unique: 132746
# [details] batch 1/664 size 200
# [details] batch 2/664 size 200
# [details] batch 3/664 size 200
# [details] batch 4/664 size 200
# [details] batch 5/664 size 200
# [details] batch 6/664 size 200
# [details] batch 7/664 size 200
# [details] batch 8/664 size 200
# [details] batch 9/664 size 200
# [details] batch 10/664 size 200
# [checkpoint] saved 2000 rows -> clinical_trials_cancer.csv
# [details] batch 11/664 size 200
# [details] batch 12/664 size 200
# [details] batch 13/664 size 200
# [details] batch 14/664 size 200
# [details] batch 15/664 size 200
# [details] batch 16/664 size 200
# [details] batch 17/664 size 200
# [details] batch 18/664 size 200
# [details] batch 19/664 size 200
# [details] batch 20/664 size 200
# [checkpoint] saved 4000 rows -> clinical_trials_cancer.csv
# [details] batch 21/664 size 200
# [details] batch 608/664 size 200
# [details] batch 609/664 size 200
# [details] batch 610/664 size 200
# [checkpoint] saved 122000 rows -> clinical_trials_cancer.csv
# [details] batch 611/664 size 200
# [details] batch 612/664 size 200
# [details] batch 613/664 size 200
# [details] batch 614/664 size 200
# [details] batch 615/664 size 200
# [details] batch 616/664 size 200
# [details] batch 617/664 size 200
# [details] batch 618/664 size 200
# [details] batch 619/664 size 200
# [details] batch 620/664 size 200
# [checkpoint] saved 124000 rows -> clinical_trials_cancer.csv
# [details] batch 621/664 size 200
# [details] batch 622/664 size 200
# [details] batch 623/664 size 200
# [details] batch 624/664 size 200
# [details] batch 625/664 size 200
# [details] batch 626/664 size 200
# [details] batch 627/664 size 200
# [details] batch 628/664 size 200
# [details] batch 629/664 size 200
# [details] batch 630/664 size 200
# [checkpoint] saved 126000 rows -> clinical_trials_cancer.csv
# [details] batch 631/664 size 200
# [details] batch 632/664 size 200
# [details] batch 633/664 size 200
# [details] batch 634/664 size 200
# [details] batch 635/664 size 200
# [details] batch 636/664 size 200
# [details] batch 637/664 size 200
# [details] batch 638/664 size 200
# [details] batch 639/664 size 200
# [details] batch 640/664 size 200
# [checkpoint] saved 128000 rows -> clinical_trials_cancer.csv
# [details] batch 641/664 size 200
# [details] batch 642/664 size 200
# [details] batch 643/664 size 200
# [details] batch 644/664 size 200
# [details] batch 645/664 size 200
# [details] batch 646/664 size 200
# [details] batch 647/664 size 200
# [details] batch 648/664 size 200
# [details] batch 649/664 size 200
# [details] batch 650/664 size 200
# [checkpoint] saved 130000 rows -> clinical_trials_cancer.csv
# [details] batch 651/664 size 200
# [details] batch 652/664 size 200
# [details] batch 653/664 size 200
# [details] batch 654/664 size 200
# [details] batch 655/664 size 200
# [details] batch 656/664 size 200
# [details] batch 657/664 size 200
# [details] batch 658/664 size 200
# [details] batch 659/664 size 200
# [details] batch 660/664 size 200
# [checkpoint] saved 132000 rows -> clinical_trials_cancer.csv
# [details] batch 661/664 size 200
# [details] batch 662/664 size 200
# [details] batch 663/664 size 200
# [details] batch 664/664 size 146
# [done] saved clinical_trials_cancer.csv: 132746 rows
# [texts] saved 132746 txt files -> studies_txt
#               NCTId                                        Study Title  \
# 0       NCT00000105  Vaccination With Tetanus and KLH to Assess Imm...
# 1       NCT00000106  41.8 Degree Centigrade Whole Body Hyperthermia...
# 2       NCT00000124         Collaborative Ocular Melanoma Study (COMS)
# 3       NCT00000134  Studies of the Ocular Complications of AIDS (S...
# 4       NCT00000136  Studies of the Ocular Complications of AIDS (S...
# ...             ...                                                ...
# 132741  NCT07150793  A Study of Real-world Treatment and Burden of ...
# 132742  NCT07150806  RYZ101 for the Treatment of Progressive or Rec...
# 132743  NCT07150884  Lactase-Assisted Control Trial On Weight GAin ...
# 132744  NCT07150949  Long-course Chemoradiotherapy or Short-course ...
# 132745  NCT07151040  Phase 1/2 Study to Evaluate TH9619 in the Trea...
#
#                                             Brief Summary  \
# 0       The purpose of this study is to learn how the ...
# 1       Recently a non-toxic system for whole body hyp...
# 2       To evaluate therapeutic interventions for pati...
# 3       To compare the relative merits of three therap...
# 4       To evaluate the relative safety and efficacy o...
# ...                                                   ...
# 132741  The main goal of this study was to describe tr...
# 132742  This phase I/II tests the safety, side effects...
# 132743  Lactose, a disaccharide that includes the mono...
# 132744  SERRAC is a prospective, multicentre, randomiz...
# 132745  This is a first in human, multi-center, open-l...
#
#                                                Conditions  \
# 0                                                  Cancer
# 1                                      Rheumatic Diseases
# 2                              Choroid Neoplasms; Uveitis
# 3       HIV Infections; Acquired Immunodeficiency Synd...
# 4               HIV Infections; Cytomegalovirus Retinitis
# ...                                                   ...
# 132741                          Myeloid Leukemia, Chronic
# 132742                               Recurrent Meningioma
# 132743  Premature - Weight 1000g-2499g or Gestation of...
# 132744  Locally Advanced Rectal Cancer; Neoadjuvant Th...
# 132745  Solid Tumor; Colorectal Cancer (CRC); Squamous...
#
#                                             Interventions  \
# 0       BIOLOGICAL: Intracel KLH Vaccine; BIOLOGICAL: ...
# 1                    DEVICE: Whole body hyperthermia unit
# 2        PROCEDURE: Brachytherapy; PROCEDURE: Eye Removal
# 3                      DRUG: Ganciclovir; DRUG: Foscarnet
# 4                      DRUG: Foscarnet; DRUG: Ganciclovir
# ...                                                   ...
# 132741
# 132742  DRUG: Actinium Ac 225 DOTATATE RYZ101; PROCEDU...
# 132743                        DIETARY_SUPPLEMENT: Lactase
# 132744  RADIATION: Long-course radiotherapy; DRUG: Oxa...
# 132745                                       DRUG: TH9619
#
#                                  Primary Outcome Measures  \
# 0       To assess whether patients can mediate an appr...
# 1
# 2
# 3                                               Morbidity
# 4                                               Mortality
# ...                                                   ...
# 132741  Number of Patients by Line of Treatment (LoT) ...
# 132742                    Progression free survival (PFS)
# 132743                                         Weigh Gain
# 132744                        Complete response (CR) rate
# 132745  Frequency of treatment-emergent adverse events...
#
#                                Secondary Outcome Measures  \
# 0                                        Tetanus Response
# 1
# 2
# 3
# 4
# ...                                                   ...
# 132741  Annual Incidence of Inpatient and Outpatient V...
# 132742  Objective response rate (ORR); Overall surviva...
# 132743                    Body length; Head circumference
# 132744  Grade 3-4 adverse effects rate; 3 year anal pr...
# 132745
#
#                    Other Outcome Measures  \
# 0
# 1
# 2
# 3
# 4
# ...                                   ...
# 132741
# 132742
# 132743  Biochemistry; Feeding intolerance
# 132744
# 132745
#
#                                    Researcher Description  \
# 0       Patients will receive each vaccine once only c...
# 1
# 2       For more than 100 years, removal of the eye (e...
# 3       CMV retinitis is the most common intraocular i...
# 4       CMV retinitis is the most common intraocular i...
# ...                                                   ...
# 132741
# 132742  PRIMARY OBJECTIVE:\n\nI. To estimate the effic...
# 132743  Lactose, a disaccharide that includes the mono...
# 132744
# 132745
#
#                                               Results URL
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3       https://clinicaltrials.gov/study/NCT00000134?t...
# 4       https://clinicaltrials.gov/study/NCT00000136?t...
# ...                                                   ...
# 132741                                               None
# 132742                                               None
# 132743                                               None
# 132744                                               None
# 132745                                               None
#
# [132746 rows x 10 columns]
